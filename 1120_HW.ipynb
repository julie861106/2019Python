# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %% [markdown]
# # 取後兩個：花瓣長度、花瓣寬度

# %%
iris = datasets.load_iris()
X = iris.data[:, 2:]
Y = iris.target

# %% [markdown]
# # 利用不同的SVM分類器
# ## SVC with linear kernel

# %%
svc = svm.SVC(kernel='linear', C=1.0).fit(X, Y)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xm, ym = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# %%
Z = svc.predict(np.c_[xm.ravel(), ym.ravel()])
Z = Z.reshape(xm.shape)
plt.contourf(xm, ym, Z, cmap="Paired", alpha=0.2)

plt.scatter(X[:, 0], X[:, 1], c=Y, cmap="Paired")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xm.min(), xm.max())
plt.ylim(ym.min(), ym.max())
plt.xticks(())
plt.yticks(())
plt.title("SVC with linear kernel")    

plt.show()

# %% [markdown]
# ## LinearSVC (linear kernel)

# %%
lin_svc = svm.LinearSVC(C=1.0).fit(X, Y)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xm, ym = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# %%
Z = lin_svc.predict(np.c_[xm.ravel(), ym.ravel()])
Z = Z.reshape(xm.shape)
plt.contourf(xm, ym, Z, cmap="Paired", alpha=0.2)

plt.scatter(X[:, 0], X[:, 1], c=Y, cmap="Paired")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xm.min(), xm.max())
plt.ylim(ym.min(), ym.max())
plt.xticks(())
plt.yticks(())
plt.title("LinearSVC (linear kernel)")    

plt.show()

# %% [markdown]
# ## SVC with RBF kernel

# %%
rbf_svc = svm.SVC(kernel='rbf', gamma=0.7, C=1.0).fit(X, Y)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xm, ym = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# %%
Z = rbf_svc.predict(np.c_[xm.ravel(), ym.ravel()])
Z = Z.reshape(xm.shape)
plt.contourf(xm, ym, Z, cmap="Paired", alpha=0.2)

plt.scatter(X[:, 0], X[:, 1], c=Y, cmap="Paired")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xm.min(), xm.max())
plt.ylim(ym.min(), ym.max())
plt.xticks(())
plt.yticks(())
plt.title("SVC with RBF kernel")    

plt.show()

# %% [markdown]
# ## SVC with polynomial (degree 3) kernel

# %%
poly_svc = svm.SVC(kernel='poly', degree=3, C=1.0).fit(X, Y)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xm, ym = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# %%
Z = poly_svc.predict(np.c_[xm.ravel(), ym.ravel()])
Z = Z.reshape(xm.shape)
plt.contourf(xm, ym, Z, cmap="Paired", alpha=0.2)

plt.scatter(X[:, 0], X[:, 1], c=Y, cmap="Paired")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xm.min(), xm.max())
plt.ylim(ym.min(), ym.max())
plt.xticks(())
plt.yticks(())
plt.title("SVC with polynomial (degree 3) kernel")    

plt.show()
