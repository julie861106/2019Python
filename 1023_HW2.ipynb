# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipywidgets import interact
plt.style.use("fivethirtyeight")

# %% [markdown]
# # 幫圖片加濾鏡

# %%
from PIL import Image, ImageFilter
cat = Image.open(r'/Users/julieyao/Documents/nccu/2019fall/python/github/cat.jpg', mode='r')
newcat01 = cat.filter(ImageFilter.EMBOSS)
newcat02 = cat.filter(ImageFilter.CONTOUR)
newcat03 = cat.filter(ImageFilter.BLUR)
plt.imshow(newcat01)

# %%
plt.imshow(newcat02)

# %%
plt.imshow(newcat03)
